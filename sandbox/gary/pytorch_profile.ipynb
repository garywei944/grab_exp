# %%
import torch
import torchvision.models as models
from torch.profiler import profile, record_function, ProfilerActivity

# %%
model = models.resnet18()
inputs = torch.randn(5, 3, 224, 224)

# %%
with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
    with record_function("model_inference"):
        model(inputs)
# Out:
# STAGE:2023-06-03 06:24:37 147292:147292 ActivityProfilerController.cpp:311] Completed Stage: Warm Up
# STAGE:2023-06-03 06:24:37 147292:147292 ActivityProfilerController.cpp:317] Completed Stage: Collection
# STAGE:2023-06-03 06:24:37 147292:147292 ActivityProfilerController.cpp:321] Completed Stage: Post Processing

# %%
print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
#                   model_inference         1.39%       1.024ms       100.00%      73.821ms      73.821ms             1
#                      aten::conv2d         3.09%       2.283ms        69.68%      51.437ms       2.572ms            20
#                 aten::convolution         0.35%     259.000us        69.56%      51.349ms       2.567ms            20
#                aten::_convolution         0.27%     203.000us        69.21%      51.090ms       2.554ms            20
#          aten::mkldnn_convolution        68.68%      50.701ms        68.93%      50.887ms       2.544ms            20
#                  aten::batch_norm         0.70%     518.000us        10.98%       8.104ms     405.200us            20
#      aten::_batch_norm_impl_index         0.16%     120.000us        10.91%       8.052ms     402.600us            20
#           aten::native_batch_norm        10.61%       7.831ms        10.74%       7.931ms     396.550us            20
#                      aten::linear         0.03%      25.000us         7.98%       5.889ms       5.889ms             1
#                       aten::addmm         7.89%       5.824ms         7.91%       5.838ms       5.838ms             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 73.821ms

# %%
print(prof.key_averages(group_by_input_shape=True).table(sort_by="cpu_time_total", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg    # of Calls                                                                      Input Shapes
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
#                   model_inference         1.39%       1.024ms       100.00%      73.821ms      73.821ms             1                                                                                []
#                      aten::conv2d         0.02%      15.000us        17.12%      12.640ms       4.213ms             3                            [[5, 512, 7, 7], [512, 512, 3, 3], [], [], [], [], []]
#                 aten::convolution         0.06%      46.000us        17.10%      12.625ms       4.208ms             3                    [[5, 512, 7, 7], [512, 512, 3, 3], [], [], [], [], [], [], []]
#                aten::_convolution         0.04%      31.000us        17.04%      12.579ms       4.193ms             3    [[5, 512, 7, 7], [512, 512, 3, 3], [], [], [], [], [], [], [], [], [], [], []]
#          aten::mkldnn_convolution        16.95%      12.509ms        17.00%      12.548ms       4.183ms             3                            [[5, 512, 7, 7], [512, 512, 3, 3], [], [], [], [], []]
#                      aten::conv2d         3.00%       2.212ms        13.12%       9.685ms       2.421ms             4                             [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], []]
#                 aten::convolution         0.07%      53.000us        13.10%       9.668ms       2.417ms             4                     [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], [], [], []]
#                aten::_convolution         0.08%      58.000us        13.02%       9.615ms       2.404ms             4     [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], [], [], [], [], [], [], []]
#          aten::mkldnn_convolution        12.90%       9.520ms        12.95%       9.557ms       2.389ms             4                             [[5, 64, 56, 56], [64, 64, 3, 3], [], [], [], [], []]
#                      aten::conv2d         0.01%       9.000us         8.79%       6.487ms       2.162ms             3                          [[5, 128, 28, 28], [128, 128, 3, 3], [], [], [], [], []]
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  --------------------------------------------------------------------------------
# Self CPU time total: 73.821ms

# %%
model = models.resnet18().cuda()
inputs = torch.randn(5, 3, 224, 224).cuda()

with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
    with record_function("model_inference"):
        model(inputs)

print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# STAGE:2023-06-03 06:27:16 147292:147292 ActivityProfilerController.cpp:311] Completed Stage: Warm Up
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        -0.02%    -368.000us       100.00%        1.574s        1.574s       0.000us         0.00%       2.055ms       2.055ms             1
#                                       aten::convolution         0.01%     161.000us        96.17%        1.513s      75.673ms       0.000us         0.00%       1.607ms      80.350us            20
#                                      aten::_convolution         0.01%     118.000us        96.16%        1.513s      75.665ms       0.000us         0.00%       1.607ms      80.350us            20
#                                 aten::cudnn_convolution         5.22%      82.120ms        96.15%        1.513s      75.659ms       1.299ms        74.36%       1.607ms      80.350us            20
#                                            aten::conv2d         0.13%       2.077ms        96.17%        1.514s      75.675ms       0.000us         0.00%       1.591ms      79.550us            20
# sm86_xmma_fprop_implicit_gemm_tf32f32_tf32f32_f32_nh...         0.00%       0.000us         0.00%       0.000us       0.000us     273.000us        15.63%     273.000us      91.000us             3
# void cudnn::ops::nchwToNhwcKernel<float, float, floa...         0.00%       0.000us         0.00%       0.000us       0.000us     251.000us        14.37%     251.000us       7.382us            34
#                                        aten::batch_norm         0.00%      34.000us         3.25%      51.164ms       2.558ms       0.000us         0.00%     228.000us      11.400us            20
#                            aten::_batch_norm_impl_index         0.00%      67.000us         3.25%      51.130ms       2.557ms       0.000us         0.00%     228.000us      11.400us            20
#                                  aten::cudnn_batch_norm         0.09%       1.338ms         3.24%      51.063ms       2.553ms     228.000us        13.05%     228.000us      11.400us            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 1.574s
# Self CUDA time total: 1.747ms
# STAGE:2023-06-03 06:27:18 147292:147292 ActivityProfilerController.cpp:317] Completed Stage: Collection
# STAGE:2023-06-03 06:27:18 147292:147292 ActivityProfilerController.cpp:321] Completed Stage: Post Processing

# %%
model = models.resnet18()
inputs = torch.randn(5, 3, 224, 224)

with profile(activities=[ProfilerActivity.CPU],
        profile_memory=True, record_shapes=True) as prof:
    model(inputs)

print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))

# (omitting some columns)
# ---------------------------------  ------------  ------------  ------------
#                              Name       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------
#                       aten::empty      94.79 Mb      94.79 Mb           121
#     aten::max_pool2d_with_indices      11.48 Mb      11.48 Mb             1
#                       aten::addmm      19.53 Kb      19.53 Kb             1
#               aten::empty_strided         572 b         572 b            25
#                     aten::resize_         240 b         240 b             6
#                         aten::abs         480 b         240 b             4
#                         aten::add         160 b         160 b            20
#               aten::masked_select         120 b         112 b             1
#                          aten::ne         122 b          53 b             6
#                          aten::eq          60 b          30 b             2
# ---------------------------------  ------------  ------------  ------------
# Self CPU time total: 53.064ms

print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.41%     220.000us         0.41%     220.000us       1.100us      90.04 Mb      90.04 Mb           200
#     aten::max_pool2d_with_indices         4.75%       2.538ms         4.75%       2.538ms       2.538ms      11.48 Mb      11.48 Mb             1
#                  aten::empty_like         0.08%      45.000us         0.12%      62.000us       3.100us      47.37 Mb       4.79 Mb            20
#                       aten::addmm         0.69%     368.000us         0.71%     381.000us     381.000us      19.53 Kb      19.53 Kb             1
#                        aten::mean         0.05%      26.000us         0.24%     130.000us     130.000us      10.00 Kb       9.99 Kb             1
#                        aten::div_         0.04%      19.000us         0.09%      50.000us      50.000us           8 b           4 b             1
#               aten::empty_strided         0.01%       6.000us         0.01%       6.000us       6.000us           4 b           4 b             1
#                      aten::conv2d         0.16%      88.000us        79.08%      42.268ms       2.113ms      47.37 Mb           0 b            20
#                 aten::convolution         0.46%     246.000us        78.91%      42.180ms       2.109ms      47.37 Mb           0 b            20
#                aten::_convolution         0.28%     147.000us        78.45%      41.934ms       2.097ms      47.37 Mb           0 b            20
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 53.453ms
#
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.41%     220.000us         0.41%     220.000us       1.100us      90.04 Mb      90.04 Mb           200
#                  aten::batch_norm         0.08%      44.000us        12.53%       6.695ms     334.750us      47.41 Mb           0 b            20
#      aten::_batch_norm_impl_index         0.20%     105.000us        12.44%       6.651ms     332.550us      47.41 Mb           0 b            20
#           aten::native_batch_norm        12.00%       6.414ms        12.24%       6.543ms     327.150us      47.41 Mb     -39.50 Kb            20
#                      aten::conv2d         0.16%      88.000us        79.08%      42.268ms       2.113ms      47.37 Mb           0 b            20
#                 aten::convolution         0.46%     246.000us        78.91%      42.180ms       2.109ms      47.37 Mb           0 b            20
#                aten::_convolution         0.28%     147.000us        78.45%      41.934ms       2.097ms      47.37 Mb           0 b            20
#          aten::mkldnn_convolution        77.82%      41.596ms        78.18%      41.787ms       2.089ms      47.37 Mb           0 b            20
#                  aten::empty_like         0.08%      45.000us         0.12%      62.000us       3.100us      47.37 Mb       4.79 Mb            20
#                  aten::max_pool2d         0.01%       5.000us         4.76%       2.543ms       2.543ms      11.48 Mb           0 b             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 53.453ms
# STAGE:2023-06-03 06:29:14 147292:147292 ActivityProfilerController.cpp:311] Completed Stage: Warm Up
# STAGE:2023-06-03 06:29:14 147292:147292 ActivityProfilerController.cpp:317] Completed Stage: Collection
# STAGE:2023-06-03 06:29:14 147292:147292 ActivityProfilerController.cpp:321] Completed Stage: Post Processing

# %%
model = models.resnet18().cuda()
inputs = torch.randn(5, 3, 224, 224).cuda()

with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA]) as prof:
    model(inputs)

prof.export_chrome_trace("trace.json")
# Out:
# STAGE:2023-06-03 06:29:43 147292:147292 ActivityProfilerController.cpp:311] Completed Stage: Warm Up
# STAGE:2023-06-03 06:29:43 147292:147292 ActivityProfilerController.cpp:317] Completed Stage: Collection
# STAGE:2023-06-03 06:29:43 147292:147292 ActivityProfilerController.cpp:321] Completed Stage: Post Processing

# %%
prof.events()
# Out:
# [<FunctionEvent id=1537 name=aten::conv2d device_type=DeviceType.CPU node_id=-1 cpu_time=435.000us start_us=234 end_us=669 cpu_children=[1538] cuda_time=77.000us name=aten::conv2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=210 is_legacy=False>,
#  <FunctionEvent id=1538 name=aten::convolution device_type=DeviceType.CPU node_id=-1 cpu_time=430.000us start_us=238 end_us=668 cpu_children=[1539] cuda_time=77.000us name=aten::convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=210 is_legacy=False>,
#  <FunctionEvent id=1539 name=aten::_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=409.000us start_us=255 end_us=664 cpu_children=[1540] cuda_time=77.000us name=aten::_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1540 name=aten::cudnn_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=398.000us start_us=263 end_us=661 cpu_children=[12618, 12619, 12620, 12624, 12625, 12626] cuda_time=77.000us name=aten::cudnn_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12618 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=1.000us start_us=578 end_us=579 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12619 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=580 end_us=580 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12620 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=1.000us start_us=581 end_us=582 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12624 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=28.000us start_us=613 end_us=641 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12625 name=cudaMemsetAsync device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=646 end_us=646 cpu_children=[] cuda_time=0.000us name=cudaMemsetAsync thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12626 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=8.000us start_us=647 end_us=655 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1541 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=31.000us start_us=699 end_us=730 cpu_children=[12631] cuda_time=2.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=211 is_legacy=False>,
#  <FunctionEvent id=12631 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=9.000us start_us=717 end_us=726 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12624 name=void cask_cudnn::computeOffsetsKernel<false, false>(cask_cudnn::ComputeOffsetsParams) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=722 end_us=724 cpu_children=[] cuda_time=2.000us name=void cask_cudnn::computeOffsetsKernel<false, false>(cask_cudnn::ComputeOffsetsParams) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12626 name=cudnn_ampere_scudnn_128x64_relu_medium_nn_v1 device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=725 end_us=800 cpu_children=[] cuda_time=75.000us name=cudnn_ampere_scudnn_128x64_relu_medium_nn_v1 thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1542 name=aten::batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=92.000us start_us=753 end_us=845 cpu_children=[1543] cuda_time=64.000us name=aten::batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=211 is_legacy=False>,
#  <FunctionEvent id=1543 name=aten::_batch_norm_impl_index device_type=DeviceType.CPU node_id=-1 cpu_time=89.000us start_us=755 end_us=844 cpu_children=[1544] cuda_time=64.000us name=aten::_batch_norm_impl_index thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=211 is_legacy=False>,
#  <FunctionEvent id=1544 name=aten::cudnn_batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=83.000us start_us=760 end_us=843 cpu_children=[1545, 12643, 12644, 12645, 1547, 1548, 1549, 1550, 1551, 12666] cuda_time=64.000us name=aten::cudnn_batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=211 is_legacy=False>,
#  <FunctionEvent id=1545 name=aten::empty_like device_type=DeviceType.CPU node_id=-1 cpu_time=8.000us start_us=777 end_us=785 cpu_children=[1546] cuda_time=0.000us name=aten::empty_like thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1546 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=780 end_us=785 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12643 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=789 end_us=789 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12644 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=790 end_us=790 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12645 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=790 end_us=790 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1547 name=aten::view device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=795 end_us=798 cpu_children=[] cuda_time=0.000us name=aten::view thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1548 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=800 end_us=804 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12631 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=801 end_us=803 cpu_children=[] cuda_time=2.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1549 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=805 end_us=808 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1550 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=812 end_us=815 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1551 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=816 end_us=818 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12666 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=10.000us start_us=829 end_us=839 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12666 name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 512, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=841 end_us=905 cpu_children=[] cuda_time=64.000us name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 512, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1552 name=aten::relu_ device_type=DeviceType.CPU node_id=-1 cpu_time=36.000us start_us=859 end_us=895 cpu_children=[1553] cuda_time=41.000us name=aten::relu_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=212 is_legacy=False>,
#  <FunctionEvent id=1553 name=aten::clamp_min_ device_type=DeviceType.CPU node_id=-1 cpu_time=19.000us start_us=865 end_us=884 cpu_children=[12672] cuda_time=41.000us name=aten::clamp_min_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12672 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=9.000us start_us=874 end_us=883 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12672 name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=906 end_us=947 cpu_children=[] cuda_time=41.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1554 name=aten::max_pool2d device_type=DeviceType.CPU node_id=-1 cpu_time=29.000us start_us=910 end_us=939 cpu_children=[1555] cuda_time=37.000us name=aten::max_pool2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=213 is_legacy=False>,
#  <FunctionEvent id=1555 name=aten::max_pool2d_with_indices device_type=DeviceType.CPU node_id=-1 cpu_time=25.000us start_us=914 end_us=939 cpu_children=[12685] cuda_time=37.000us name=aten::max_pool2d_with_indices thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=213 is_legacy=False>,
#  <FunctionEvent id=12685 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=7.000us start_us=931 end_us=938 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12685 name=void at::native::(anonymous namespace)::max_pool_forward_nchw<float, float>(int, float const*, long, long, long, int, int, int, int, int, int, int, int, int, int, float*, long*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=948 end_us=985 cpu_children=[] cuda_time=37.000us name=void at::native::(anonymous namespace)::max_pool_forward_nchw<float, float>(int, float const*, long, long, long, int, int, int, int, int, int, int, int, int, int, float*, long*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1556 name=aten::conv2d device_type=DeviceType.CPU node_id=-1 cpu_time=81.000us start_us=962 end_us=1043 cpu_children=[1557] cuda_time=67.000us name=aten::conv2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=214 is_legacy=False>,
#  <FunctionEvent id=1557 name=aten::convolution device_type=DeviceType.CPU node_id=-1 cpu_time=79.000us start_us=963 end_us=1042 cpu_children=[1558] cuda_time=67.000us name=aten::convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=214 is_legacy=False>,
#  <FunctionEvent id=1558 name=aten::_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=73.000us start_us=969 end_us=1042 cpu_children=[1559] cuda_time=67.000us name=aten::_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1559 name=aten::cudnn_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=68.000us start_us=973 end_us=1041 cpu_children=[12695, 12696, 12697, 12701, 12703, 12705, 12706, 12707] cuda_time=67.000us name=aten::cudnn_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12695 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=984 end_us=984 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12696 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=984 end_us=984 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12697 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=985 end_us=985 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12701 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=8.000us start_us=1002 end_us=1010 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12701 name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1011 end_us=1021 cpu_children=[] cuda_time=10.000us name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12703 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1012 end_us=1016 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12703 name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1023 end_us=1026 cpu_children=[] cuda_time=3.000us name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12705 name=cudaFuncSetAttribute device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1028 end_us=1031 cpu_children=[] cuda_time=0.000us name=cudaFuncSetAttribute thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12706 name=cudaFuncSetAttribute device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1031 end_us=1031 cpu_children=[] cuda_time=0.000us name=cudaFuncSetAttribute thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12707 name=INVALID device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1032 end_us=1037 cpu_children=[] cuda_time=0.000us name=INVALID thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12707 name=sm86_xmma_fprop_implicit_gemm_indexed_tf32f32_tf32f32_f32_nhwckrsc_nchw_tilesize128x64x32_stage4_warpsize2x2x1_g1_tensor16x8x8_execute_kernel_cudnn device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1038 end_us=1092 cpu_children=[] cuda_time=54.000us name=sm86_xmma_fprop_implicit_gemm_indexed_tf32f32_tf32f32_f32_nhwckrsc_nchw_tilesize128x64x32_stage4_warpsize2x2x1_g1_tensor16x8x8_execute_kernel_cudnn thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1560 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=11.000us start_us=1057 end_us=1068 cpu_children=[12713] cuda_time=2.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=215 is_legacy=False>,
#  <FunctionEvent id=12713 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1062 end_us=1066 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1561 name=aten::batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=51.000us start_us=1079 end_us=1130 cpu_children=[1562] cuda_time=13.000us name=aten::batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=215 is_legacy=False>,
#  <FunctionEvent id=1562 name=aten::_batch_norm_impl_index device_type=DeviceType.CPU node_id=-1 cpu_time=50.000us start_us=1080 end_us=1130 cpu_children=[1563] cuda_time=13.000us name=aten::_batch_norm_impl_index thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=215 is_legacy=False>,
#  <FunctionEvent id=1563 name=aten::cudnn_batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=48.000us start_us=1081 end_us=1129 cpu_children=[1564, 12725, 12726, 12727, 1566, 1567, 1568, 1569, 1570, 12748] cuda_time=13.000us name=aten::cudnn_batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=215 is_legacy=False>,
#  <FunctionEvent id=1564 name=aten::empty_like device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1089 end_us=1094 cpu_children=[1565] cuda_time=0.000us name=aten::empty_like thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1565 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1089 end_us=1093 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12713 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1094 end_us=1096 cpu_children=[] cuda_time=2.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12725 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1097 end_us=1097 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12726 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1098 end_us=1098 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12727 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1099 end_us=1099 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1566 name=aten::view device_type=DeviceType.CPU node_id=-1 cpu_time=1.000us start_us=1100 end_us=1101 cpu_children=[] cuda_time=0.000us name=aten::view thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1567 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1103 end_us=1106 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1568 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1107 end_us=1110 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1569 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1111 end_us=1114 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1570 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=1115 end_us=1117 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12748 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=7.000us start_us=1120 end_us=1127 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12748 name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 128, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1129 end_us=1142 cpu_children=[] cuda_time=13.000us name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 128, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1571 name=aten::relu_ device_type=DeviceType.CPU node_id=-1 cpu_time=18.000us start_us=1139 end_us=1157 cpu_children=[1572] cuda_time=4.000us name=aten::relu_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=216 is_legacy=False>,
#  <FunctionEvent id=1572 name=aten::clamp_min_ device_type=DeviceType.CPU node_id=-1 cpu_time=10.000us start_us=1142 end_us=1152 cpu_children=[12754] cuda_time=4.000us name=aten::clamp_min_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12754 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1146 end_us=1151 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12754 name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1152 end_us=1156 cpu_children=[] cuda_time=4.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1573 name=aten::conv2d device_type=DeviceType.CPU node_id=-1 cpu_time=47.000us start_us=1166 end_us=1213 cpu_children=[1574] cuda_time=63.000us name=aten::conv2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=217 is_legacy=False>,
#  <FunctionEvent id=1574 name=aten::convolution device_type=DeviceType.CPU node_id=-1 cpu_time=46.000us start_us=1167 end_us=1213 cpu_children=[1575] cuda_time=63.000us name=aten::convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=217 is_legacy=False>,
#  <FunctionEvent id=1575 name=aten::_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=41.000us start_us=1171 end_us=1212 cpu_children=[1576] cuda_time=63.000us name=aten::_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1576 name=aten::cudnn_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=38.000us start_us=1173 end_us=1211 cpu_children=[12765, 12766, 12767, 12771, 12773, 12775, 12776, 12777] cuda_time=63.000us name=aten::cudnn_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12765 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1182 end_us=1182 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12766 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1183 end_us=1183 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12767 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1183 end_us=1183 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12771 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1191 end_us=1195 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12771 name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1197 end_us=1204 cpu_children=[] cuda_time=7.000us name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12773 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1197 end_us=1200 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12775 name=cudaFuncSetAttribute device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1203 end_us=1203 cpu_children=[] cuda_time=0.000us name=cudaFuncSetAttribute thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12776 name=cudaFuncSetAttribute device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1204 end_us=1204 cpu_children=[] cuda_time=0.000us name=cudaFuncSetAttribute thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12777 name=INVALID device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1205 end_us=1208 cpu_children=[] cuda_time=0.000us name=INVALID thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12773 name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1206 end_us=1209 cpu_children=[] cuda_time=3.000us name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12777 name=sm86_xmma_fprop_implicit_gemm_indexed_tf32f32_tf32f32_f32_nhwckrsc_nchw_tilesize128x64x32_stage4_warpsize2x2x1_g1_tensor16x8x8_execute_kernel_cudnn device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1210 end_us=1263 cpu_children=[] cuda_time=53.000us name=sm86_xmma_fprop_implicit_gemm_indexed_tf32f32_tf32f32_f32_nhwckrsc_nchw_tilesize128x64x32_stage4_warpsize2x2x1_g1_tensor16x8x8_execute_kernel_cudnn thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1577 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=12.000us start_us=1226 end_us=1238 cpu_children=[12783] cuda_time=2.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=218 is_legacy=False>,
#  <FunctionEvent id=12783 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=6.000us start_us=1232 end_us=1238 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1578 name=aten::batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=49.000us start_us=1249 end_us=1298 cpu_children=[1579] cuda_time=12.000us name=aten::batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=218 is_legacy=False>,
#  <FunctionEvent id=1579 name=aten::_batch_norm_impl_index device_type=DeviceType.CPU node_id=-1 cpu_time=47.000us start_us=1250 end_us=1297 cpu_children=[1580] cuda_time=12.000us name=aten::_batch_norm_impl_index thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=218 is_legacy=False>,
#  <FunctionEvent id=1580 name=aten::cudnn_batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=46.000us start_us=1251 end_us=1297 cpu_children=[1581, 12795, 12796, 12797, 1583, 1584, 1585, 1586, 1587, 12818] cuda_time=12.000us name=aten::cudnn_batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=218 is_legacy=False>,
#  <FunctionEvent id=1581 name=aten::empty_like device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1259 end_us=1264 cpu_children=[1582] cuda_time=0.000us name=aten::empty_like thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1582 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1259 end_us=1263 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12783 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1265 end_us=1267 cpu_children=[] cuda_time=2.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12795 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1267 end_us=1267 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12796 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1268 end_us=1268 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12797 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1268 end_us=1268 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1583 name=aten::view device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=1270 end_us=1272 cpu_children=[] cuda_time=0.000us name=aten::view thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1584 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1273 end_us=1276 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1585 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1277 end_us=1281 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1586 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=1282 end_us=1284 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1587 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=1285 end_us=1287 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12818 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1289 end_us=1294 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12818 name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 128, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1296 end_us=1308 cpu_children=[] cuda_time=12.000us name=void cudnn::bn_fw_tr_1C11_kernel_NCHW<float, float, int, 128, true, 1, true>(cudnnTensorStruct, float const*, cudnnTensorStruct, float*, float const*, float const*, float, float, float*, float*, float*, float*, float, float) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1588 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=15.000us start_us=1302 end_us=1317 cpu_children=[12823] cuda_time=11.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=219 is_legacy=False>,
#  <FunctionEvent id=12823 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1309 end_us=1314 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12823 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3> >(int, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1316 end_us=1327 cpu_children=[] cuda_time=11.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3> >(int, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1589 name=aten::relu_ device_type=DeviceType.CPU node_id=-1 cpu_time=15.000us start_us=1325 end_us=1340 cpu_children=[1590] cuda_time=4.000us name=aten::relu_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=220 is_legacy=False>,
#  <FunctionEvent id=1590 name=aten::clamp_min_ device_type=DeviceType.CPU node_id=-1 cpu_time=8.000us start_us=1329 end_us=1337 cpu_children=[12829] cuda_time=4.000us name=aten::clamp_min_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12829 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=1332 end_us=1336 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12829 name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1338 end_us=1342 cpu_children=[] cuda_time=4.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1591 name=aten::conv2d device_type=DeviceType.CPU node_id=-1 cpu_time=50.000us start_us=1352 end_us=1402 cpu_children=[1592] cuda_time=64.000us name=aten::conv2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=221 is_legacy=False>,
#  <FunctionEvent id=1592 name=aten::convolution device_type=DeviceType.CPU node_id=-1 cpu_time=48.000us start_us=1353 end_us=1401 cpu_children=[1593] cuda_time=64.000us name=aten::convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=221 is_legacy=False>,
#  <FunctionEvent id=1593 name=aten::_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=42.000us start_us=1357 end_us=1399 cpu_children=[1594] cuda_time=64.000us name=aten::_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1594 name=aten::cudnn_convolution device_type=DeviceType.CPU node_id=-1 cpu_time=39.000us start_us=1360 end_us=1399 cpu_children=[12840, 12841, 12842, 12846, 12848, 12850, 12852] cuda_time=64.000us name=aten::cudnn_convolution thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12840 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1370 end_us=1370 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12841 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1370 end_us=1370 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12842 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1371 end_us=1371 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12846 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=1378 end_us=1383 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12846 name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=1385 end_us=1392 cpu_children=[] cuda_time=7.000us name=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12848 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=1385 end_us=1388 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=12850 name=cudaFuncSetAttribute device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=1391 end_us=1391 cpu_children=[] cuda_time=0.000us name=cudaFuncSetAttribute thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
# ...
#  <FunctionEvent id=1867 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=13.000us start_us=4642 end_us=4655 cpu_children=[14005] cuda_time=2.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=273 is_legacy=False>,
#  <FunctionEvent id=14005 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=6.000us start_us=4648 end_us=4654 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1868 name=aten::batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=56.000us start_us=4666 end_us=4722 cpu_children=[1869] cuda_time=9.000us name=aten::batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=273 is_legacy=False>,
#  <FunctionEvent id=1869 name=aten::_batch_norm_impl_index device_type=DeviceType.CPU node_id=-1 cpu_time=54.000us start_us=4667 end_us=4721 cpu_children=[1870] cuda_time=9.000us name=aten::_batch_norm_impl_index thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=273 is_legacy=False>,
#  <FunctionEvent id=1870 name=aten::cudnn_batch_norm device_type=DeviceType.CPU node_id=-1 cpu_time=52.000us start_us=4669 end_us=4721 cpu_children=[1871, 14017, 14018, 14019, 1873, 1874, 1875, 1876, 1877, 14040] cuda_time=9.000us name=aten::cudnn_batch_norm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=273 is_legacy=False>,
#  <FunctionEvent id=1871 name=aten::empty_like device_type=DeviceType.CPU node_id=-1 cpu_time=6.000us start_us=4679 end_us=4685 cpu_children=[1872] cuda_time=0.000us name=aten::empty_like thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1872 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=4680 end_us=4684 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14017 name=cudaStreamIsCapturing device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=4688 end_us=4688 cpu_children=[] cuda_time=0.000us name=cudaStreamIsCapturing thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14018 name=cudaStreamGetPriority device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=4689 end_us=4689 cpu_children=[] cuda_time=0.000us name=cudaStreamGetPriority thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14019 name=cudaDeviceGetStreamPriorityRange device_type=DeviceType.CPU node_id=-1 cpu_time=0.000us start_us=4689 end_us=4689 cpu_children=[] cuda_time=0.000us name=cudaDeviceGetStreamPriorityRange thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1873 name=aten::view device_type=DeviceType.CPU node_id=-1 cpu_time=1.000us start_us=4691 end_us=4692 cpu_children=[] cuda_time=0.000us name=aten::view thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1874 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=3.000us start_us=4693 end_us=4696 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14005 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=4693 end_us=4695 cpu_children=[] cuda_time=2.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2> >(int, at::native::CUDAFunctorOnSelf_add<long>, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1875 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=4697 end_us=4701 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1876 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=4704 end_us=4706 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1877 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=2.000us start_us=4707 end_us=4709 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14040 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=4712 end_us=4717 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14040 name=void cudnn::bn_fw_tr_1C11_singleread<float, 512, true, 1, 2, 0>(cudnn::bn_fw_tr_1C11_args<float>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=4720 end_us=4729 cpu_children=[] cuda_time=9.000us name=void cudnn::bn_fw_tr_1C11_singleread<float, 512, true, 1, 2, 0>(cudnn::bn_fw_tr_1C11_args<float>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1878 name=aten::add_ device_type=DeviceType.CPU node_id=-1 cpu_time=13.000us start_us=4725 end_us=4738 cpu_children=[14046] cuda_time=3.000us name=aten::add_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=274 is_legacy=False>,
#  <FunctionEvent id=14046 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=4731 end_us=4736 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14046 name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3> >(int, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=4738 end_us=4741 cpu_children=[] cuda_time=3.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3> >(int, at::native::CUDAFunctor_add<float>, at::detail::Array<char*, 3>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1879 name=aten::relu_ device_type=DeviceType.CPU node_id=-1 cpu_time=15.000us start_us=4745 end_us=4760 cpu_children=[1880] cuda_time=2.000us name=aten::relu_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=275 is_legacy=False>,
#  <FunctionEvent id=1880 name=aten::clamp_min_ device_type=DeviceType.CPU node_id=-1 cpu_time=9.000us start_us=4748 end_us=4757 cpu_children=[14052] cuda_time=2.000us name=aten::clamp_min_ thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14052 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=4.000us start_us=4752 end_us=4756 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14052 name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=4757 end_us=4759 cpu_children=[] cuda_time=2.000us name=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::launch_clamp_scalar(at::TensorIteratorBase&, c10::Scalar, c10::Scalar, at::native::detail::ClampLimits)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1881 name=aten::adaptive_avg_pool2d device_type=DeviceType.CPU node_id=-1 cpu_time=45.000us start_us=4791 end_us=4836 cpu_children=[1882] cuda_time=4.000us name=aten::adaptive_avg_pool2d thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=276 is_legacy=False>,
#  <FunctionEvent id=1882 name=aten::mean device_type=DeviceType.CPU node_id=-1 cpu_time=40.000us start_us=4796 end_us=4836 cpu_children=[14065] cuda_time=4.000us name=aten::mean thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=276 is_legacy=False>,
#  <FunctionEvent id=14065 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=10.000us start_us=4823 end_us=4833 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14065 name=void at::native::reduce_kernel<512, 1, at::native::ReduceOp<float, at::native::MeanOps<float, float>, unsigned int, float, 4> >(at::native::ReduceOp<float, at::native::MeanOps<float, float>, unsigned int, float, 4>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=4834 end_us=4838 cpu_children=[] cuda_time=4.000us name=void at::native::reduce_kernel<512, 1, at::native::ReduceOp<float, at::native::MeanOps<float, float>, unsigned int, float, 4> >(at::native::ReduceOp<float, at::native::MeanOps<float, float>, unsigned int, float, 4>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1883 name=aten::flatten device_type=DeviceType.CPU node_id=-1 cpu_time=21.000us start_us=4845 end_us=4866 cpu_children=[1884] cuda_time=0.000us name=aten::flatten thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=277 is_legacy=False>,
#  <FunctionEvent id=1884 name=aten::_reshape_alias device_type=DeviceType.CPU node_id=-1 cpu_time=10.000us start_us=4856 end_us=4866 cpu_children=[] cuda_time=0.000us name=aten::_reshape_alias thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=277 is_legacy=False>,
#  <FunctionEvent id=1885 name=aten::linear device_type=DeviceType.CPU node_id=-1 cpu_time=229.000us start_us=4886 end_us=5115 cpu_children=[1886] cuda_time=0.000us name=aten::linear thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=278 is_legacy=False>,
#  <FunctionEvent id=1886 name=aten::t device_type=DeviceType.CPU node_id=-1 cpu_time=24.000us start_us=4893 end_us=4917 cpu_children=[1887] cuda_time=0.000us name=aten::t thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=278 is_legacy=False>,
#  <FunctionEvent id=1887 name=aten::transpose device_type=DeviceType.CPU node_id=-1 cpu_time=12.000us start_us=4903 end_us=4915 cpu_children=[1888] cuda_time=0.000us name=aten::transpose thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1888 name=aten::as_strided device_type=DeviceType.CPU node_id=-1 cpu_time=6.000us start_us=4909 end_us=4915 cpu_children=[] cuda_time=0.000us name=aten::as_strided thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=1889 name=aten::addmm device_type=DeviceType.CPU node_id=-1 cpu_time=195.000us start_us=4921 end_us=5116 cpu_children=[1890, 14081, 14083] cuda_time=8.000us name=aten::addmm thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=279 is_legacy=False>,
#  <FunctionEvent id=1890 name=aten::empty device_type=DeviceType.CPU node_id=-1 cpu_time=5.000us start_us=4966 end_us=4971 cpu_children=[] cuda_time=0.000us name=aten::empty thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14081 name=cudaOccupancyMaxActiveBlocksPerMultiprocessorWithFlags device_type=DeviceType.CPU node_id=-1 cpu_time=10.000us start_us=5072 end_us=5082 cpu_children=[] cuda_time=0.000us name=cudaOccupancyMaxActiveBlocksPerMultiprocessorWithFlags thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14083 name=cudaLaunchKernel device_type=DeviceType.CPU node_id=-1 cpu_time=15.000us start_us=5093 end_us=5108 cpu_children=[] cuda_time=0.000us name=cudaLaunchKernel thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14083 name=void gemmSN_TN_kernel<float, 128, 16, 2, 4, 6, 7, false, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float> >(cublasGemmSmallNParams<cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float>, float>) device_type=DeviceType.CUDA node_id=-1 cpu_time=0.000us start_us=5108 end_us=5116 cpu_children=[] cuda_time=8.000us name=void gemmSN_TN_kernel<float, 128, 16, 2, 4, 6, 7, false, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float> >(cublasGemmSmallNParams<cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float const>, cublasGemvTensorStridedBatched<float>, float>) thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>,
#  <FunctionEvent id=14088 name=cudaDeviceSynchronize device_type=DeviceType.CPU node_id=-1 cpu_time=25.000us start_us=5487 end_us=5512 cpu_children=[] cuda_time=0.000us name=cudaDeviceSynchronize thread=1 input_shapes=[] cpu_memory_usage=0 cuda_memory_usage=0 is_async=False is_remote=False seq_nr=-1 is_legacy=False>]

# %%
# with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
with record_function("model_inference"):
    model(inputs)

# %%
del prof

# %%
print(profile().key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(profile().key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
#
# File ~/mambaforge/envs/grab/lib/python3.10/site-packages/torch/profiler/profiler.py:183, in _KinetoProfile.key_averages(self, group_by_input_shape, group_by_stack_n)
#     175 def key_averages(self, group_by_input_shape: bool = False, group_by_stack_n: int = 0):
#     176     """Averages events, grouping them by operator name and (optionally) input shapes and
#     177     stack.
#     178
#    (...)
#     181         when creating profiler context manager.
#     182     """
# --> 183     assert self.profiler
#     184     return self.profiler.key_averages(group_by_input_shape, group_by_stack_n)
#
# AssertionError:
