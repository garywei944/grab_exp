# %%
import pandas as pd
import wandb

api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("grab/grab-cifar10")

for run in runs:
    if run.config.get('balance_type') == 'recursive-pair':
        run.config['depth'] = 5
    run.update()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#      10 if run.config.get('balance_type') == 'recursive-pair':
#      11     run.config['depth'] = 5
# ---> 12 run.update()
#
# File ~/mambaforge/envs/grab/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/mambaforge/envs/grab/lib/python3.10/site-packages/wandb/apis/public.py:1903, in Run.update(self)
#    1889 """Persist changes to the run object to the wandb backend."""
#    1890 mutation = gql(
#    1891     """
# ...
